# %%
import random



def compare(guess,number):
    if guess > number:
        print("Too high")
    elif guess < number :
        print("Too low")
    
logo = """
  / _ \_   _  ___  ___ ___  /__   \ |__   ___    /\ \ \_   _ _ __ ___ | |__   ___ _ __ 
 / /_\/ | | |/ _ \/ __/ __|   / /\/ '_ \ / _ \  /  \/ / | | | '_ ` _ \| '_ \ / _ \ '__|
/ /_\\| |_| |  __/\__ \__ \  / /  | | | |  __/ / /\  /| |_| | | | | | | |_) |  __/ |   
\____/ \__,_|\___||___/___/  \/   |_| |_|\___| \_\ \/  \__,_|_| |_| |_|_.__/ \___|_|  
"""   

print(logo)

print("Welcome to the Number Guessing Game")
print("I'm thinking a number between 1 and 100")
number = random.randint(1,100)

level = input("Choose a difficulty. Type 'easy' or 'normal' and 'hard': ")

if level == "easy":
    life = 10
elif level == "hard":
    life = 3
elif level == "normal":
    life = 5
    
    
is_game = True



while is_game:
    print(f"you have {life} attempts remaining to guess the number ")
    guess = int(input("Make a guess: "))
    
    if guess == number:
        is_game = False
        print(f"Congratlations you guess the number {guess}")
        
    else:
        compare(guess,number)
        life-=1
        if life == 0:
            is_game = False
            print(f"You lose the number was {number}")
        else:
            print("Guess again")
# Out:
#   / _ \_   _  ___  ___ ___  /__   \ |__   ___    /\ \ \_   _ _ __ ___ | |__   ___ _ __
#  / /_\/ | | |/ _ \/ __/ __|   / /\/ '_ \ / _ \  /  \/ / | | | '_ ` _ \| '_ \ / _ \ '__|
# / /_\| |_| |  __/\__ \__ \  / /  | | | |  __/ / /\  /| |_| | | | | | | |_) |  __/ |
# \____/ \__,_|\___||___/___/  \/   |_| |_|\___| \_\ \/  \__,_|_| |_| |_|_.__/ \___|_|
#
# Welcome to the Number Guessing Game
# I'm thinking a number between 1 and 100
# Choose a difficulty. Type 'easy' or 'normal' and 'hard': easy
# you have 10 attempts remaining to guess the number
# Make a guess: 50
# Too high
# Guess again
# you have 9 attempts remaining to guess the number
# Make a guess: 25
# Too low
# Guess again
# you have 8 attempts remaining to guess the number
# Make a guess: 37
# Too high
# Guess again
# you have 7 attempts remaining to guess the number
# Make a guess: 31
# Too low
# Guess again
# you have 6 attempts remaining to guess the number
# Make a guess: 34
# Too high
# Guess again
# you have 5 attempts remaining to guess the number
# Make a guess: 32
# Congratlations you guess the number 32
