# %%
import random

logo = """
.------.            _     _            _    _            _    
|A_  _ |.          | |   | |          | |  (_)          | |   
|( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
| \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
|  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   < 
`-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\\
      |  \/ K|                            _/ |                
      `------'                           |__/           
"""
    





def compare(user_score, computer_score):
 
  if user_score > 21 and computer_score > 21:
    return "You went over. You lose 😤"


  if user_score == computer_score:
    return "Draw 🙃"
  elif computer_score == 0:
    return "Lose, opponent has Blackjack 😱"
  elif user_score == 0:
    return "Win with a Blackjack 😎"
  elif user_score > 21:
    return "You went over. You lose 😭"
  elif computer_score > 21:
    return "Opponent went over. You win 😁"
  elif user_score > computer_score:
    return "You win 😃"
  else:
    return "You lose 😤"

def calculate_score(cards):
    
    if sum(cards) == 21 and len(cards) ==2:
        return 0
    if 11 in cards and sum(cards) > 21:
        cards.remove(11)
        cards.append(1)
    
    return sum(cards)
    
def deal_card():
    
    cards = [11,2,3,4,5,6,7,8,9,10,10,10]
    card = random.choice(cards)
    return card


def play_game():
    
    print(logo)

    user_cards=[]
    computer_cards=[]
    is_game_over = False


    for _ in range(2):
        user_cards.append(deal_card())
        computer_cards.append(deal_card())

    
    
    while not is_game_over:
        user_score = calculate_score(user_cards)

        computer_score = calculate_score(computer_cards)

        print(f" Your card : {user_cards}, current score {user_score}")

        print(f" Computer's first card {computer_cards[0]}")

        if user_score == 0 or computer_score == 0 or user_score >21:
            is_game_over = True
        else:
    
            user_should_deal = input("Type 'y' to get another card, type 'n' to pass:")
            if user_should_deal == "y":
                user_cards.append(deal_card())
    
            else:
                is_game_over = True
    
    while computer_score !=0 and computer_score < 17:
        computer_cards.append(deal_card())
        computer_score = calculate_score(computer_cards)
    print(f"Your final hand : {user_cards}, final score {user_score}") 
    print(f"Computer's final hand : {computer_cards}, final score {computer_score}")    
    print(compare(user_score, computer_score)) 
        
        
while input("Do you want to play a game of Blackjack? Type 'y' or 'n' : ") == "y":
    play_game()
# Out:
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [10, 7], current score 17
#  Computer's first card 10
# Type 'y' to get another card, type 'n' to pass:n
# Your final hand : [10, 7], final score 17
# Computer's final hand : [10, 5, 4], final score 19
# You lose 😤
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [10, 5], current score 15
#  Computer's first card 4
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [10, 5, 10], current score 25
#  Computer's first card 4
# Your final hand : [10, 5, 10], final score 25
# Computer's final hand : [4, 10, 10], final score 24
# You went over. You lose 😤
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [4, 2], current score 6
#  Computer's first card 11
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [4, 2, 10], current score 16
#  Computer's first card 11
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [4, 2, 10, 9], current score 25
#  Computer's first card 11
# Your final hand : [4, 2, 10, 9], final score 25
# Computer's final hand : [11, 7], final score 18
# You went over. You lose 😭
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [8, 9], current score 17
#  Computer's first card 3
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [8, 9, 9], current score 26
#  Computer's first card 3
# Your final hand : [8, 9, 9], final score 26
# Computer's final hand : [3, 10, 7], final score 20
# You went over. You lose 😭
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [8, 11], current score 19
#  Computer's first card 10
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [8, 10, 1], current score 19
#  Computer's first card 10
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [8, 10, 1, 7], current score 26
#  Computer's first card 10
# Your final hand : [8, 10, 1, 7], final score 26
# Computer's final hand : [10, 5, 7], final score 22
# You went over. You lose 😤
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [10, 7], current score 17
#  Computer's first card 10
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [10, 7, 10], current score 27
#  Computer's first card 10
# Your final hand : [10, 7, 10], final score 27
# Computer's final hand : [10, 8], final score 18
# You went over. You lose 😭
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [5, 4], current score 9
#  Computer's first card 3
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [5, 4, 11], current score 20
#  Computer's first card 3
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [5, 4, 7, 1], current score 17
#  Computer's first card 3
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [5, 4, 7, 1, 6], current score 23
#  Computer's first card 3
# Your final hand : [5, 4, 7, 1, 6], final score 23
# Computer's final hand : [3, 2, 2, 8, 3], final score 18
# You went over. You lose 😭
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [7, 10], current score 17
#  Computer's first card 8
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [7, 10, 9], current score 26
#  Computer's first card 8
# Your final hand : [7, 10, 9], final score 26
# Computer's final hand : [8, 3, 8], final score 19
# You went over. You lose 😭
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [9, 8], current score 17
#  Computer's first card 8
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [9, 8, 3], current score 20
#  Computer's first card 8
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [9, 8, 3, 4], current score 24
#  Computer's first card 8
# Your final hand : [9, 8, 3, 4], final score 24
# Computer's final hand : [8, 10], final score 18
# You went over. You lose 😭
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [9, 5], current score 14
#  Computer's first card 9
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [9, 5, 5], current score 19
#  Computer's first card 9
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [9, 5, 5, 4], current score 23
#  Computer's first card 9
# Your final hand : [9, 5, 5, 4], final score 23
# Computer's final hand : [9, 2, 5, 10], final score 26
# You went over. You lose 😤
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [2, 6], current score 8
#  Computer's first card 10
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [2, 6, 6], current score 14
#  Computer's first card 10
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [2, 6, 6, 2], current score 16
#  Computer's first card 10
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [2, 6, 6, 2, 5], current score 21
#  Computer's first card 10
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [2, 6, 6, 2, 5, 10], current score 31
#  Computer's first card 10
# Your final hand : [2, 6, 6, 2, 5, 10], final score 31
# Computer's final hand : [10, 2, 6], final score 18
# You went over. You lose 😭
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [11, 10], current score 0
#  Computer's first card 10
# Your final hand : [11, 10], final score 0
# Computer's final hand : [10, 7], final score 17
# Win with a Blackjack 😎
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [10, 10], current score 20
#  Computer's first card 2
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [10, 10, 4], current score 24
#  Computer's first card 2
# Your final hand : [10, 10, 4], final score 24
# Computer's final hand : [2, 10, 10], final score 22
# You went over. You lose 😤
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [2, 4], current score 6
#  Computer's first card 10
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [2, 4, 9], current score 15
#  Computer's first card 10
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [2, 4, 9, 9], current score 24
#  Computer's first card 10
# Your final hand : [2, 4, 9, 9], final score 24
# Computer's final hand : [10, 4, 1, 10], final score 25
# You went over. You lose 😤
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [10, 10], current score 20
#  Computer's first card 5
# Type 'y' to get another card, type 'n' to pass:n
# Your final hand : [10, 10], final score 20
# Computer's final hand : [5, 2, 5, 8], final score 20
# Draw 🙃
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [6, 8], current score 14
#  Computer's first card 3
# Type 'y' to get another card, type 'n' to pass:n
# Your final hand : [6, 8], final score 14
# Computer's final hand : [3, 10, 5], final score 18
# You lose 😤
# Do you want to play a game of Blackjack? Type 'y' or 'n' : n

# %%
# Out:
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [6, 3], current score 9
#  Computer's first card 8
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [6, 3, 9], current score 18
#  Computer's first card 8
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [6, 3, 9, 2], current score 20
#  Computer's first card 8
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [6, 3, 9, 2, 10], current score 30
#  Computer's first card 8
# Your final hand : [6, 3, 9, 2, 10], final score 30
# Computer's final hand : [8, 4, 10], final score 22
# You went over. You lose 😤
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [2, 10], current score 12
#  Computer's first card 3
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [2, 10, 10], current score 22
#  Computer's first card 3
# Your final hand : [2, 10, 10], final score 22
# Computer's final hand : [3, 7, 10], final score 20
# You went over. You lose 😭
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [10, 10], current score 20
#  Computer's first card 3
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [10, 10, 3], current score 23
#  Computer's first card 3
# Your final hand : [10, 10, 3], final score 23
# Computer's final hand : [3, 4, 5, 10], final score 22
# You went over. You lose 😤
# Do you want to play a game of Blackjack? Type 'y' or 'n' : y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#  Your card : [7, 10], current score 17
#  Computer's first card 2
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [7, 10, 1], current score 18
#  Computer's first card 2
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [7, 10, 1, 3], current score 21
#  Computer's first card 2
# Type 'y' to get another card, type 'n' to pass:y
#  Your card : [7, 10, 1, 3, 6], current score 27
#  Computer's first card 2
# Your final hand : [7, 10, 1, 3, 6], final score 27
# Computer's final hand : [2, 5, 11], final score 18
# You went over. You lose 😭
# Do you want to play a game of Blackjack? Type 'y' or 'n' :
